# %% [markdown]
# # 数据预处理

# %% [markdown]
# ### 读入文件

# %%
#当前工作路径
import os
# print os.getcwd()
print(os.getcwd())
# Out:
# C:\Users\dell\project\CustomerFlowForecastsOnKoubei.com\code

# %%
import pandas as pd
shop_info_column=["shop_id","city_name","location_id","per_pay","score","comment_cnt",
                  "shop_level","cate_1_name","cate_2_name","cate_3_name"]
shop_info=pd.read_csv(r"..\data\shop_info.txt",names=shop_info_column)
# shop_info.info()
shop_info.shape
# Out:
# (2000, 10)

# %%
user_pay_column=["user_id","shop_id","time_stamp"]
user_pay_reader=pd.read_csv(r"..\data\user_pay.txt",names=user_pay_column,chunksize=10000)
# Out:
#        user_id  shop_id           time_stamp
# 0     22127870     1862  2015-12-25 17:00:00
# 1      3434231     1862  2016-10-05 11:00:00
# 2     16955285     1862  2016-02-10 15:00:00
# 3     13799128     1862  2016-01-13 14:00:00
# 4     13799128     1862  2016-07-05 12:00:00
# 5     20244878     1862  2016-09-17 15:00:00
# 6     20244878     1862  2016-05-29 16:00:00
# 7       438444     1862  2016-02-22 17:00:00
# 8     22003193     1862  2016-08-07 15:00:00
# 9     20244878     1862  2016-04-17 16:00:00
# 10     9034387     1862  2016-03-18 19:00:00
# 11    13211167     1862  2016-09-29 20:00:00
# 12    18329438     1862  2016-03-20 18:00:00
# 13    20244878     1862  2016-06-26 15:00:00
# 14    10303270     1862  2016-01-01 18:00:00
# 15    12590929     1862  2016-04-17 17:00:00
# 16    12590929     1862  2016-02-28 13:00:00
# 17    17609360     1862  2016-10-15 17:00:00
# 18    14438936     1862  2016-06-26 15:00:00
# 19    15262746     1862  2016-10-18 19:00:00
# ...
